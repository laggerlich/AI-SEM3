# %%
import sys

import numpy as np

import cv2 as cv
import matplotlib.pyplot as plt

# %%
img = cv.imread("starry_night.jpg")

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (600, 752, 3)

# %% [markdown]
# # Задание 1

# %% [markdown]
# #### Скрипт по переводу изображения из BRG в RGB

# %%
img = img[:,:,[2,1,0]]
plt.imshow(img)

# %% [markdown]
# # Задание 2

# %% [markdown]
# #### Меняем местами луну и голубую воронку в центре

# %%
img_patch1 = img[100:320, 275:475, :]
plt.imshow(img_patch1)

# %%
img_patch2 = img[40:180, 600:740, :]
plt.imshow(img_patch2)

# %%
img_patch1=cv.resize(img_patch1,(140,140))
plt.imshow(img_patch1)

# %%
img_patch2=cv.resize(img_patch2,(200,220))
plt.imshow(img_patch2)

# %%
img[100:320, 275:475, :] = img_patch2
img[40:180, 600:740, :] = img_patch1

plt.imshow(img)

# %% [markdown]
# # Задание 3
#
# #### Делаем из ночи день

# %%
img_bgr = cv.imread("starry_night.jpg")
img_rgb = cv.cvtColor(img_bgr, cv.COLOR_BGR2RGB)

plt.imshow(img_rgb)

# %%
img_mod = img_rgb
blue_channel = img_mod[:, :, 2]
green_channel = img_mod[:, :, 1]
red_channel = img_mod[:, :, 0]
img_mod[:, :, 1] = red_channel
img_mod[:, :, 0] = green_channel
img_mod[:, :, 2] = blue_channel/1.8
cv.convertScaleAbs(img_rgb, img_mod, 1.8, 10)
plt.imshow(img_mod)
